# %% [markdown]
# 作業一
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
#  1.你選的這組資料為何重要
# 我選擇的資料為Stanford Dogs Dataset (https://www.kaggle.com/jessicali9530/stanford-dogs-dataset),資料包含了120品種和20580張犬隻照片.資料庫建立者試圖將不同品種犬隻透過照片的分類而加以區別出來.由於我聯想到這與應用在智慧型手機上的生物特徵辨認系統,不禁覺得是一個很有趣也很有挑戰的題材,因此選擇了這組資料.
#
#  2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 這資料的來源也是源自kaggle上的其他database,但是資料建立者覺得原先資料略有不足,所以加以改進之後重新建立了這個database.
#
#  3.蒐集而來的資料型態為何
#  資料型態為圖片.
#
#  4.這組資料想解決的問題如何評估
# 這組資料希望可以分辨不同品種的犬隻,但是同時不被犬隻的顏色,年齡,相似特徵干擾與混淆.所以我們可以蒐集已知不同品種,但是擁有相近顏色,年齡,類似特徵的犬隻加以測試,由判斷的準確來加以評估.

# %% [markdown]
# 作業二
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 提升業績的最直接的方式就是增加載客量,假設車隊主要攬客方式是藉由app叫車,可以分成兩個面向討論:
# 第一個為app的曝光度與普及度,使更多人下載與使用車隊的app.以擴展目前的客群.
# -->去分析app的曝光度與下載次數,去掌握目前的客群規模,並分析下載數量與業績成長的關聯性.理想上,下載次數不斷成長也會帶動業績不斷成長.所以發現當月下載次數的成長不如上個月時,需要進一步加強宣傳與行銷.
#
# 第二個為如何提升現有客群的服務體驗,減少客群的流失.
# -->統計每個用戶使用app的頻率與成功叫車的次數,直覺上如果用戶使用app的頻率不斷減少,可能代表客戶覺得車隊的車次太少難以叫車或是抵達迎客地時間過長,因此選擇其他交通工具.由於從叫車app可以獲得地點與時間的資料,如果抓出app使用頻率下降客戶的叫車地點與時間去做統計,就可以知道在那些時段時應該把車隊的空車派往哪些路段,以有效增加的轎車的成功率.
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 可以透過app store和google store去了解每個月的下載次數.然後透過叫車app去蒐集客戶的轎車頻率,時間與地點.
#
# 3. 蒐集而來的資料型態為何
# 資料型態以數值(下載數,時間)還有地點的資料
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 第一面向的話可以藉由每個月叫車app下載數和業績去做關聯,檢驗兩者是否有正相關.第二面向則可以去監控原本app使用頻率下降的用戶,觀察一段時間後其使用頻率是否有慢慢回升.

# %% [markdown]
# # 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label= 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y, yp):
    import math
    mse = MSE = sum((y-yp)**2)/len(y)
    return mse
MSE = mean_squared_error(y, y_hat)


def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
MAE = mean_absolute_error(y, y_hat)

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 235.515
# The Mean absolute error is 12.121
